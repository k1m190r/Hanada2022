# %%
import numpy as np
import matplotlib.pyplot as plt

np.seterr(divide="ignore", invalid="ignore")
# Out:
# {'divide': 'ignore', 'over': 'warn', 'under': 'ignore', 'invalid': 'ignore'}

# %% [markdown]
# # Box-Muller Method
#
# $ p,q ∈ 𝒰(0,1)$
#
# $$
# x = \sqrt{-2 log(p)} cos(2πq)\\
# y = \sqrt{-2 log(p)} sin(2πq)
# \tag{2.10}
# $$

# %%
N = 10_000
p = np.random.rand(N)
q = np.random.rand(N)

# %%
nx = np.sqrt(-2*np.log(p)) * np.cos(2*np.pi*q)
ny = np.sqrt(-2*np.log(p)) * np.sin(2*np.pi*q)

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(nx, ny, s=1, alpha=0.1)

# %%
fig, ax = plt.subplots(1,1)
ax.hist(nx, 100);

# %%
nx.mean(), nx.std()
# Out:
# (-0.00559055736568754, 0.9967286698871574)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # I DONT UNDERSTAND STUFF BELOW...

# %% [markdown]
# $$ ∫_1^4 x^2 dx $$

# %%
x = np.linspace(-10, 10, 1000)
y = x ** 2

fig, ax = plt.subplots(1,1)
ax.scatter(x, y, s=1)

dx = x[1]-x[0]
y.sum() * dx
# Out:
# 668.6700046726739

# %%
from scipy.stats import norm

# %%
Px = norm.pdf(x)

fig, ax = plt.subplots(1,1)
ax.scatter(x, Px)

Px.sum()*dx
# Out:
# 1.0000000000000002

# %%
(Px*y).sum()*dx
# Out:
# 0.9999999999999999

# %%
(nx**2).sum()/N
# Out:
# 0.993499295706681
